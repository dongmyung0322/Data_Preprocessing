# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
img = cv2.imread('./data/cat.png')
plt.imshow(img)
plt.show()

# %%
#print(img.shape)
#height = img.shape[0]
#width = img.shape[1]
#channel = img.shape[2]
#print(width)

#img.resize(width,width,3)
#print(img.shape)
plt.imshow(img)
plt.show()

# %%
def find_longer(width,height):
    if width>height:
        return width
    else:
        return height

a = find_longer(img.shape[1],img.shape[0])
background = np.full((a,a,3), (0,0,0), dtype=np.uint8)
img_after = background+a
#img.resize(a,a,3)
plt.imshow(img_after)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
